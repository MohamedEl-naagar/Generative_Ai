# %%
# !pip install sqlalchemy
# Out:
# Requirement already satisfied: sqlalchemy in ./venv/lib/python3.12/site-packages (2.0.51)
# Requirement already satisfied: greenlet>=1 in ./venv/lib/python3.12/site-packages (from sqlalchemy) (3.5.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in ./venv/lib/python3.12/site-packages (from sqlalchemy) (4.16.0)

# %%
from sqlalchemy import Column, String , Integer , create_engine

# %%
from sqlalchemy.orm import sessionmaker,declarative_base

# %%
engine = create_engine("sqlite:///mydb.db")

# define base
Base = declarative_base()

# design table 
class User(Base):
    __tablename__ = "users"

    id = Column(Integer,primary_key=True)
    name = Column(String,nullable=False)
    age = Column(Integer,nullable=False)

    def __represent__(self):
        return f"User: {self.id} , name: {self.name}, age: {self.age}"

Base.metadata.create_all(engine)

# %%
Session = sessionmaker(bind=engine)
session = Session()

user1 = User(name="mohamed elnagar",age=23)
user2 = User(name="farida",age=3)

# add single
session.add(user1)
session.add(user2)

# %%
# save changes (commit)
session.commit()

# %%
# Read Data
users = session.query(User).all()
#print(users)

for  u in users:
    print(u.id,u.name,u.age)
# Out:
# 1 mohamed elnagar 23
# 2 farida 3
# 3 mohamed elnagar 23
# 4 farida 3

# %%
# read single item
user = session.query(User).filter_by(name="farida").first()
print(user)
user.age = 44
session.commit()
print(user.id,user.name,user.age)
# Out:
# <__main__.User object at 0x74d2048ce630>
# 2 farida 44
